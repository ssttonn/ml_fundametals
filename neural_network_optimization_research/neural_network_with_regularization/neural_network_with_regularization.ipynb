# %%
import sys
sys.path.insert(1, '../')
sys.path.insert(1, '../../')

from subutils import load_2D_dataset
import numpy as np
import matplotlib.pyplot as plt
import sklearn, sklearn.datasets
import scipy
from utils import *

# %matplotlib inline
plt.rcParams['figure.figsize'] = (7.0, 4.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %%
train_X, train_Y, test_X, test_Y = load_2D_dataset()

# %%
n_x, n_y = input_output_layer_sizes(train_X, train_Y)
layer_dims = [n_x, 20, 20, n_y]
activations = [relu, relu, sigmoid]

# %%
parameters = he_initialize_parameters(layer_dims)

parameters, costs = nn_model(train_X, train_Y, layer_dims, parameters, activations, number_of_iterations=100, learning_rate=0.1, print_cost=True)
parameters
# Out:
# Cost after iteration 0: 0.773579
# {'W1': array([[ 1.62652166, -0.60598475],
#         [-0.45891135, -1.08799438],
#         [ 0.91566694, -2.29216759],
#         [ 1.74009912, -0.75139393],
#         [ 0.34835355, -0.25732182],
#         [ 1.52263316, -2.05457879],
#         [-0.28262874, -0.36742675],
#         [ 1.1858595 , -1.11014477],
#         [ 0.04687774, -0.93956608],
#         [ 0.05255058,  0.54303666],
#         [-1.31432747,  1.07840162],
#         [ 0.88340831,  0.49614661],
#         [ 0.91725843, -0.68775122],
#         [-0.09543271, -0.9022209 ],
#         [-0.22444708,  0.49339645],
#         [-0.73087764, -0.43999092],
#         [-0.65496629, -0.89354912],
#         [-0.78939998,  0.04289895],
#         [-1.23626009,  0.26436778],
#         [ 1.62986453,  0.76706078]]),
#  'b1': array([[ 0.01892301],
#         [-0.01249843],
#         [ 0.08485602],
#         [-0.06818845],
#         [ 0.13597567],
#         [ 0.12452084],
#         [ 0.11054193],
# ...

# %%
predictions_train = predict(parameters, activations, train_X)

metrics(train_Y[0], predictions_train[0])
# Out:
# Precision: 79.16666666666666 %
# Recall: 89.62264150943396 %
# Accuracy: 82.93838862559242 %

# %%
predictions_test = predict(parameters, activations, test_X)
metrics(test_Y[0], predictions_test[0])
# Out:
# Precision: 76.53061224489795 %
# Recall: 86.20689655172413 %
# Accuracy: 82.5 %

# %%
plt.title("Model without regularization")
axes = plt.gca()
axes.set_xlim([-0.75,0.40])
axes.set_ylim([-0.75,0.65])
plot_decision_boundary(lambda x: predict(parameters, activations, x.T), train_X, train_Y)

# %%
plt.title("Model without regularization")
axes = plt.gca()
axes.set_xlim([-0.75,0.40])
axes.set_ylim([-0.75,0.65])
plot_decision_boundary(lambda x: predict(parameters, activations, x.T), test_X, test_Y)

# %%
parameters = he_initialize_parameters(layer_dims)

parameters, costs = nn_model(train_X, train_Y, layer_dims, parameters, activations, number_of_iterations=100, learning_rate=0.25, print_cost=True, lamd=0.4)
parameters
# Out:
# Cost after iteration 0: 0.773579
# {'W1': array([[ 1.56267923, -0.55981994],
#         [-0.44430277, -1.04583678],
#         [ 0.9177316 , -2.15474073],
#         [ 1.65971461, -0.71873304],
#         [ 0.38018652, -0.22079294],
#         [ 1.54324311, -1.88780401],
#         [-0.25526845, -0.31491896],
#         [ 1.24489567, -0.95599887],
#         [ 0.16791575, -0.81251009],
#         [ 0.03871066,  0.50834223],
#         [-1.53071228,  0.92968264],
#         [ 0.83234874,  0.46530144],
#         [ 0.92372083, -0.60413733],
#         [-0.08204787, -0.85671333],
#         [-0.21301894,  0.46845333],
#         [-0.74830849, -0.44661761],
#         [-0.68147429, -0.86615389],
#         [-0.90344235,  0.01968411],
#         [-1.37395216,  0.22424952],
#         [ 1.54442443,  0.72502708]]),
#  'b1': array([[ 0.3342923 ],
#         [-0.0072721 ],
#         [ 0.15231069],
#         [-0.06967905],
#         [ 0.19772842],
#         [ 0.30840397],
#         [ 0.19066876],
# ...

# %%
predictions_train = predict(parameters, activations, train_X)

metrics(train_Y[0], predictions_train[0])
# Out:
# Precision: 90.74074074074075 %
# Recall: 92.45283018867924 %
# Accuracy: 91.4691943127962 %

# %%
predictions_test = predict(parameters, activations, test_X)

metrics(test_Y[0], predictions_test[0])
# Out:
# Precision: 93.97590361445783 %
# Recall: 89.65517241379311 %
# Accuracy: 93.0 %

# %%
plt.title("Model without regularization")
axes = plt.gca()
axes.set_xlim([-0.75,0.40])
axes.set_ylim([-0.75,0.65])
plot_decision_boundary(lambda x: predict(parameters, activations, x.T), train_X, train_Y)

# %%
plt.title("Model without regularization")
axes = plt.gca()
axes.set_xlim([-0.75,0.40])
axes.set_ylim([-0.75,0.65])
plot_decision_boundary(lambda x: predict(parameters, activations, x.T), test_X, test_Y)

# %%
# Dropout Regularization
parameters = he_initialize_parameters(layer_dims)

parameters, costs = nn_model(train_X, train_Y, layer_dims, parameters, activations, number_of_iterations=50000, learning_rate=0.075, print_cost=True, keep_prob=0.6)
parameters
# Out:
# Cost after iteration 0: 0.781180
# Cost after iteration 100: 0.496466
# Cost after iteration 200: 0.395003
# Cost after iteration 300: 0.353835
# Cost after iteration 400: 0.335166
# Cost after iteration 500: 0.282048
# Cost after iteration 600: 0.262207
# Cost after iteration 700: 0.328850
# Cost after iteration 800: 0.266390
# Cost after iteration 900: 0.267531
# Cost after iteration 1000: 0.281274
# Cost after iteration 1100: 0.287820
# Cost after iteration 1200: 0.271218
# Cost after iteration 1300: 0.263707
# Cost after iteration 1400: 0.276443
# Cost after iteration 1500: 0.263301
# Cost after iteration 1600: 0.275805
# Cost after iteration 1700: 0.292112
# Cost after iteration 1800: 0.264782
# Cost after iteration 1900: 0.243994
# Cost after iteration 2000: 0.239709
# Cost after iteration 2100: 0.285999
# Cost after iteration 2200: 0.283416
# Cost after iteration 2300: 0.270211
# Cost after iteration 2400: 0.315924
# Cost after iteration 2500: 0.256165
# ...

# %%
predictions_train = predict(parameters, activations, train_X)

metrics(train_Y[0], predictions_train[0])
# Out:
# Precision: 96.19047619047619 %
# Recall: 95.28301886792453 %
# Accuracy: 95.73459715639811 %

# %%
predictions_test = predict(parameters, activations, test_X)

metrics(test_Y[0], predictions_test[0])
# Out:
# Precision: 94.11764705882352 %
# Recall: 91.95402298850574 %
# Accuracy: 94.0 %

# %%
plt.title("Model without regularization")
axes = plt.gca()
axes.set_xlim([-0.75,0.40])
axes.set_ylim([-0.75,0.65])
plot_decision_boundary(lambda x: predict(parameters, activations, x.T), train_X, train_Y)

# %%
plt.title("Model without regularization")
axes = plt.gca()
axes.set_xlim([-0.75,0.40])
axes.set_ylim([-0.75,0.65])
plot_decision_boundary(lambda x: predict(parameters, activations, x.T), test_X, test_Y)
